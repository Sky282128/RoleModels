# %% [markdown]
# ## **Role Models**
# Presented by Aldrin G. Hsu, Wesley Brian T. Sy, and Gian Martin C. Carlos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import seaborn as sns

# %% [markdown]
# ### **Dataset Overview**
# The dataset includes national-level data from the Philippines showcasing the **percentage share of total family income and total family expenditure**, disaggregated by **each region, province, and highly urbanized city (HUC)** for the years **2018**, **2021**, and **2023**. These figures allow for data analysis in the trends of income distribution and household spending behavior across each geographic locations and time period in the Philippines.
#
# ---
#
# ### **How the Dataset Was Collected**
# The dataset was collected by the **Philippine Statistics Authority (PSA)** as part of their **Family Income and Expenditure Survey (FIES)**. The FIES is conducted every three years using techniques such as probability sampling to gather economic data across the country. The Surveys are administered in person by PSA field staffs.
#
# ---
#
# ### **Potential Implications of Data Collection**
# Since the survey relies on **self-reported data**, responses may be affected by **recall bias or underreporting**, especially on sensitive financial matters. Additionally, regions that are remote and households in the informal sector may have underpresented and inconsistent data due to logistical, economic, and social reasons. Factors such as these mentioned can affect the accuracy and generalizability of the income and expenditure shares reported in the dataset.
#
# ---
#
# ### **Structure of the Data**
# The dataset is **structured and tabular**.
#
# Each **row** represents:
# - A specific **geographical unit** (Region, Province, or HUC) for a **specific year** (2018, 2021, or 2023).
#
# Each **column** represents:
# - Either a share of **total income** (Table 6) or **total expenditure** (Table 7).
#
# **Total Number of Observations**:
# - Varies based on the number of geographic units reported for each year.
#
# **Attributes/Features Present**:
# - `Year` – The survey year
# - `Geographic_Unit` – Region/Province/HUC
# - `Income_Share` – % share to total national income
# - `Expenditure_Share` – % share to total national expenditure
#
# ---
#
# ### **Brief Description of the Attributes**
#
# | Attribute Name            | Description |
# |---------------------------|-------------|
# | `Year`                    | Survey year (2018, 2021, or 2023) |
# | `Region`                  | Name of the region (e.g., NCR, Region IV-A) |
# | `Province` / `HUC`        | Name of the province or highly urbanized city |
# | `Income_Share (%)`        | Share of the geographic unit to the total national family income |
# | `Expenditure_Share (%)`   | Share of the geographic unit to the total national family expenditure |

# %%
#dfIncome = pd.read_excel("Table 6. 2018, 2021 and 2023p Share to Total Annual Family Income, by Region, Province and HUC.xlsx", engine="openpyxl")
#dfExpenditure = pd.read_excel("Table 7. 2018, 2021 and 2023p Share to Total Family Expenditure, by Region, Province and HUC.xlsx", engine="openpyxl")

# %%
#dfIncome.head(10)
#dfExpenditure.head(10)

# %% [markdown]
# ### **Data Cleaning**
# As seen in the dataframe above, there are unnecessary NaNs due to the way the files are formatted. To make the data easier to read and clean, we split the two datasets into six CSV files. The data in the files are based on whether they are for Income or Expenditure and based on their year (2018, 2021, or 2023). Note that we did not make new CSV files for Percentage Point Change since those values could be derived using the yearly data.

# %%
#Uncomment if using Google Colab
#from google.colab import drive
#drive.mount('/content/drive')
#Income18 = pd.read_csv("/content/drive/MyDrive/CSMODEL/I18.csv")
#Income21 = pd.read_csv("/content/drive/MyDrive/CSMODEL/I21.csv")
#Income23 = pd.read_csv("/content/drive/MyDrive/CSMODEL/I23.csv")
#Expenditure18 = pd.read_csv("/content/drive/MyDrive/CSMODEL/E18.csv")
#Expenditure21 = pd.read_csv("/content/drive/MyDrive/CSMODEL/E21.csv")
#Expenditure23 = pd.read_csv("/content/drive/MyDrive/CSMODEL/E23.csv")

#Table 6. 2018, 2021 and 2023p Share to Total Annual Family Income, by Region, Province and HUC
Income18 = pd.read_csv("I18.csv")
Income21 = pd.read_csv("I21.csv")
Income23 = pd.read_csv("I23.csv")

#Table 7. 2018, 2021 and 2023p Share to Total Family Expenditure, by Region, Province and HUC
Expenditure18 = pd.read_csv("E18.csv")
Expenditure21 = pd.read_csv("E21.csv")
Expenditure23 = pd.read_csv("E23.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# You may use this code block to see the data of one of our dataframes.

# %%
#Initial state of the dataset
#Income18.head(10)
#Income21.head(10)
#Income23.head(10)

#Expenditure18.head(10)
#Expenditure21.head(10)
Expenditure23.head(10)
# Out:
#                                           Unnamed: 0  PHILIPPINES  \
# 0                        Share to Family Expenditure        100.0
# 1                   Food and Non-Alcoholic Beverages         40.9
# 2                              Food Consumed at Home         35.3
# 3           Food Regularly Consumed Outside the Home          5.6
# 4      Service for Processing Primary Goods for F...          0.0
# 5                    Alcoholic Beverages and Tobacco          1.4
# 6                              Clothing and Footwear          1.9
# 7   Housing, Water, Electricity, Gas and Other Fuels         22.9
# 8      Furnishings and Routine Household Maintenance          2.6
# 9                                             Health          3.0
#
#   NATIONAL CAPITAL REGION City of Manila  City of Mandaluyong  \
# 0                  100.0          100.0                 100.0
# 1                   37.7           44.1                  36.2
# 2                   27.8           30.2                  25.3
# 3                    9.9           13.9                  10.9
# 4                    -              -                     0.0
# 5                    1.2            1.4                   1.0
# 6                    1.6            1.5                   1.8
# 7                   28.8           26.2                  30.5
# 8                    2.6            1.9                   2.4
# 9                    2.8            2.3                   3.0
#
#   City of San Juan Quezon City City of Marikina  City of Pasig  \
# 0           100.0       100.0            100.0           100.0
# 1            31.4        39.8             35.4            32.0
# 2            22.5        26.3             24.5            25.2
# 3             9.0        13.5             10.9             6.8
# 4             -           -                -               0.0
# 5             0.6         1.6              1.0             1.2
# 6             2.0         1.5              1.4             1.7
# 7            31.0        25.8             28.1            30.2
# 8             3.1         2.9              3.0             2.5
# 9             2.3         3.5              4.6             3.5
#
#   City of Caloocan  ... Dinagat Islands  \
# 0           100.0   ...          100.0
# 1            40.9   ...           45.2
# 2            32.8   ...           44.7
# 3             8.2   ...            0.6
# 4             -     ...            -
# 5             0.9   ...            1.4
# 6             1.6   ...            2.2
# 7            25.8   ...           19.6
# 8             2.3   ...            2.8
# 9             2.2   ...            2.5
#
#   BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (includes the 63 barangays from Cotabato for 2023)2/  \
# 0                                              100.0
# 1                                               57.5
# 2                                               54.3
# 3                                                3.2
# 4                                                0.0
# 5                                                1.2
# 6                                                3.0
# 7                                               14.6
# 8                                                2.2
# 9                                                1.4
#
#    Basilan  Lanao Del Sur Maguindanao Maguindanao del Sur  \
# 0   100.0           100.0       100.0               100.0
# 1    55.1            62.5        55.2                56.7
# 2    53.8            58.7        51.0                51.8
# 3     1.4             3.8         4.2                 4.8
# 4     0.0             0.0         0.0                 0.0
# 5     1.4             1.1         1.2                 1.2
# 6     2.9             2.2         3.0                 2.9
# 7    14.6            13.2        14.3                12.9
# 8     2.1             1.5         2.7                 2.8
# 9     1.1             1.4         1.4                 1.3
#
#   Maguindanao del Norte   Sulu Tawi-Tawi Cotabato City
# 0                100.0   100.0       100           100
# 1                 53.6    64.7      46.3            47
# 2                 50.1    63.2      46.1          41.6
# 3                  3.6     1.5       0.2           5.3
# 4                  -       0.0         0             -
# 5                  1.3     0.8       2.4           0.9
# 6                  3.2     3.3       3.7           2.9
# 7                 15.8    10.3      26.6          19.1
# 8                  2.7     2.6       2.4           2.6
# 9                  1.5     1.4       0.8           1.8
#
# [10 rows x 139 columns]

# %% [markdown]
# Since our dataset is split into 6 dataframes, it will be efficient to use loops for the operations that will follow.

# %%
IE = {
    "Income18": Income18,
    "Income21": Income21,
    "Income23": Income23,
    "Expenditure18": Expenditure18,
    "Expenditure21": Expenditure21,
    "Expenditure23": Expenditure23
}

# %% [markdown]
# We observed that the regions (ie. NCR and BARMM) and the cities (ie. City of Manila and City of Mandaluyong) are in the first row, while variables such as Wage/Salaries and Food and Non-Alcoholic Beverages are in the first column. Thus, we transposed each dataframe to avoid confusion on which are the variables and which are the observations.

# %%
for df in IE:
  IE[df] = IE[df].transpose()

#Observe the contents for Maguindanao del Norte and Maguindanao del Sur
IE["Expenditure18"].tail(10)
# Out:
#                                                          0       1       2   \
# Dinagat Islands                                      100.0    45.9    43.0
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   100.0    59.9    54.0
# Basilan                                              100.0    58.5    53.6
# Lanao Del Sur                                        100.0    59.5    53.6
# Maguindanao                                          100.0    59.3    50.9
# Maguindanao del Sur                                     NaN     NaN     NaN
# Maguindanao del Norte                                   NaN     NaN     NaN
# Sulu                                                 100.0    66.0    65.3
# Tawi-Tawi                                            100.0    61.0    59.6
# Cotabato City                                        100.0    53.4    43.4
#
#                                                         3      4      5   \
# Dinagat Islands                                       2.9    -      1.4
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    5.8    -      1.6
# Basilan                                               4.9    -      1.7
# Lanao Del Sur                                         5.9    -      1.4
# Maguindanao                                           8.4    -      2.1
# Maguindanao del Sur                                    NaN    NaN    NaN
# Maguindanao del Norte                                  NaN    NaN    NaN
# Sulu                                                  0.7    -      1.3
# Tawi-Tawi                                             1.4    -      1.2
# Cotabato City                                        10.0    -      1.0
#
#                                                        6       7      8   \
# Dinagat Islands                                      3.4    14.5    2.2
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   2.5    14.6    1.3
# Basilan                                              2.8    11.0    1.3
# Lanao Del Sur                                        2.5    15.3    1.8
# Maguindanao                                          2.6    14.6    1.2
# Maguindanao del Sur                                   NaN     NaN    NaN
# Maguindanao del Norte                                 NaN     NaN    NaN
# Sulu                                                 2.3    11.9    0.9
# Tawi-Tawi                                            3.1    15.4    1.2
# Cotabato City                                        2.1    19.5    1.3
#
#                                                        9      10     11  \
# Dinagat Islands                                      3.0    4.9    1.1
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   1.1    4.6    1.2
# Basilan                                              1.4    5.3    1.3
# Lanao Del Sur                                        1.4    4.8    1.0
# Maguindanao                                          1.1    4.8    1.3
# Maguindanao del Sur                                   NaN    NaN    NaN
# Maguindanao del Norte                                 NaN    NaN    NaN
# Sulu                                                 0.6    3.1    1.0
# Tawi-Tawi                                            0.6    5.6    1.2
# Cotabato City                                        1.4    4.8    1.7
#
#                                                        12     13     14  \
# Dinagat Islands                                      0.9    3.8    0.4
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   0.4    2.1    0.0
# Basilan                                              0.4    1.6    0.1
# Lanao Del Sur                                        0.4    1.8    0.0
# Maguindanao                                          0.5    1.5    0.0
# Maguindanao del Sur                                   NaN    NaN    NaN
# Maguindanao del Norte                                 NaN    NaN    NaN
# Sulu                                                 0.3    4.6    0.0
# Tawi-Tawi                                            0.4    0.9    -
# Cotabato City                                        0.4    2.1    0.0
#
#                                                        15     16     17  \
# Dinagat Islands                                      -      6.1    5.1
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   -      6.1    1.3
# Basilan                                              -      6.8    3.2
# Lanao Del Sur                                        -      6.4    1.1
# Maguindanao                                          -      5.6    1.5
# Maguindanao del Sur                                   NaN    NaN    NaN
# Maguindanao del Norte                                 NaN    NaN    NaN
# Sulu                                                 -      5.4    0.4
# Tawi-Tawi                                            -      6.2    0.9
# Cotabato City                                        -      6.8    1.9
#
#                                                        18     19
# Dinagat Islands                                      5.4    1.9
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...   1.9    1.4
# Basilan                                              3.7    1.1
# Lanao Del Sur                                        0.8    1.9
# Maguindanao                                          2.7    1.3
# Maguindanao del Sur                                   NaN    NaN
# Maguindanao del Norte                                 NaN    NaN
# Sulu                                                 0.9    1.4
# Tawi-Tawi                                            1.3    1.1
# Cotabato City                                        2.4    1.2

# %% [markdown]
# We observed that Maguindanao del Norte and Maguindanao del Sur are the only regions that lack a majority of their expected values in both Income and Expenditure. Thus, we removed the rows for Maguindanao del Norte and and Maguindanao del Sur from all of our dataframes.

# %%
for df in IE:
  IE[df].drop(labels="Maguindanao del Sur", inplace=True)
  IE[df].drop(labels="Maguindanao del Norte", inplace=True)

IE["Expenditure23"].tail(10)
# Out:
#                                                          0       1       2   \
# Surigao Del Norte                                     100.0    44.4    43.2
# Surigao Del Sur                                      100.0    48.5    46.4
# Dinagat Islands                                      100.0    45.2    44.7
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    100.0    57.5    54.3
# Basilan                                              100.0    55.1    53.8
# Lanao Del Sur                                         100.0    62.5    58.7
# Maguindanao                                           100.0    55.2    51.0
# Sulu                                                  100.0    64.7    63.2
# Tawi-Tawi                                               100    46.3    46.1
# Cotabato City                                           100      47    41.6
#
#                                                        3      4      5   \
# Surigao Del Norte                                     1.3    0.0    1.6
# Surigao Del Sur                                      2.1    -      1.1
# Dinagat Islands                                      0.6    -      1.4
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    3.2    0.0    1.2
# Basilan                                              1.4    0.0    1.4
# Lanao Del Sur                                         3.8    0.0    1.1
# Maguindanao                                           4.2    0.0    1.2
# Sulu                                                  1.5    0.0    0.8
# Tawi-Tawi                                             0.2      0    2.4
# Cotabato City                                         5.3      -    0.9
#
#                                                        6       7      8   \
# Surigao Del Norte                                     1.8    21.2    2.7
# Surigao Del Sur                                      1.5    18.4    2.3
# Dinagat Islands                                      2.2    19.6    2.8
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    3.0    14.6    2.2
# Basilan                                              2.9    14.6    2.1
# Lanao Del Sur                                         2.2    13.2    1.5
# Maguindanao                                           3.0    14.3    2.7
# Sulu                                                  3.3    10.3    2.6
# Tawi-Tawi                                             3.7    26.6    2.4
# Cotabato City                                         2.9    19.1    2.6
#
#                                                        9      10     11  \
# Surigao Del Norte                                     2.9    5.9    2.8
# Surigao Del Sur                                      2.3    5.5    2.6
# Dinagat Islands                                      2.5    5.3    1.9
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    1.4    5.0    1.7
# Basilan                                              1.1    5.7    1.6
# Lanao Del Sur                                         1.4    4.1    1.2
# Maguindanao                                           1.4    5.5    2.2
# Sulu                                                  1.4    3.8    1.3
# Tawi-Tawi                                             0.8    6.8    1.5
# Cotabato City                                         1.8    6.3    2.9
#
#                                                        12     13     14  \
# Surigao Del Norte                                     0.7    4.6    0.0
# Surigao Del Sur                                      0.6    3.1    0.1
# Dinagat Islands                                      0.9    3.6    0.1
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    0.7    2.1    0.0
# Basilan                                              0.9    3.5    -
# Lanao Del Sur                                         0.5    2.5    0.1
# Maguindanao                                           0.9    1.9    0.0
# Sulu                                                  0.4    0.7    0.0
# Tawi-Tawi                                             0.5    2.2      -
# Cotabato City                                         1.1    2.6    0.1
#
#                                                        15     16     17  \
# Surigao Del Norte                                     2.5    3.4    1.2
# Surigao Del Sur                                      2.5    3.9    1.2
# Dinagat Islands                                      2.3    3.6    2.5
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    0.8    4.7    1.6
# Basilan                                              0.8    5.3    3.0
# Lanao Del Sur                                         1.2    4.0    1.1
# Maguindanao                                           0.5    4.8    1.6
# Sulu                                                  0.3    5.6    1.2
# Tawi-Tawi                                             0.1    4.4    1.1
# Cotabato City                                         1.2    4.4    2.5
#
#                                                        18     19
# Surigao Del Norte                                     3.1    1.3
# Surigao Del Sur                                      4.4    2.0
# Dinagat Islands                                      4.5    1.8
# BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM ...    2.3    1.4
# Basilan                                              1.6    0.7
# Lanao Del Sur                                         1.4    2.1
# Maguindanao                                           3.6    1.2
# Sulu                                                  2.5    1.3
# Tawi-Tawi                                             1.1    0.3
# Cotabato City                                         3.2    1.5

# %% [markdown]
# We observed in our dataframes for Expenditure that variables such as Service for Processing Primary Goods for Food and Non- alcoholic Beverages and Hotels (Accommodation Services) have many missing values represented by "-". We replaced all instances of "-" with 0 since it seemed reasonable for those variables to not contribute to the total expenditure of the given regions/cities.

# %%
for df in IE:
  IE[df].iloc[1:, 1:] = (
    IE[df].iloc[1:, 1:]
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
  )

# %% [markdown]
# Lastly, the dataset contains the mean statistics from each region -- which we will not be using as the dataset already contains the data from where the regional data is derived from, causing it to appear as a duplicate for the purpose of this study. Hence, we will be dropping these entries from the dataframes.

# %%
for df in IE:
  IE[df].drop(labels=["PHILIPPINES",
                              "NATIONAL CAPITAL REGION",
                              "CAR - CORDILLERA ADMINISTRATIVE REGION",
                              "REGION I - ILOCOS REGION",
                              "REGION II - CAGAYAN VALLEY",
                              "REGION III - CENTRAL LUZON",
                              "REGION IVA - CALABARZON",
                              "MIMAROPA REGION",
                              "REGION V - BICOL REGION",
                              "REGION VI - WESTERN VISAYAS",
                              "NEGROS ISLAND REGION",
                              "REGION VII - CENTRAL VISAYAS",
                              "REGION VIII - EASTERN VISAYAS",
                              "REGION IX - ZAMBOANGA PENINSULA",
                              "REGION X - NORTHERN MINDANAO",
                              "REGION XI - DAVAO REGION",
                              "REGION XII - SOCCSKSARGEN1/",
                              "CARAGA",
                              "BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (includes the 63 barangays from Cotabato for 2023)2/"
                              ],inplace=True)

# %%
#Final state of the dataset
IE["Income18"].name = "Income18"
IE["Income21"].name = "Income21"
IE["Income23"].name = "Income23"
IE["Expenditure18"].name = "Expenditure18"
IE["Expenditure21"].name = "Expenditure21"
IE["Expenditure23"].name = "Expenditure23"

# %% [markdown]
# This concludes the data cleaning for our dataset. You may use this code block to see how our data is currently organized in our dataframes.

# %%
#IE["Income18"].head(30)
#IE["Income21"].tail()
IE["Income23"].head()

#IE["Expenditure18"].tail()
#IE["Expenditure21"].tail()
#IE["Expenditure23"].head(10)
# Out:
#                                          0              1   \
# Unnamed: 0           Share to Family Income  Wage/Salaries
# City of Manila                        100.0           64.3
# City of Mandaluyong                   100.0           63.5
# City of San Juan                      100.0           55.9
# Quezon City                           100.0           69.5
#
#                                              2                          3   \
# Unnamed: 0           Entrepreneurial Activities  Cash Receipts from Abroad
# City of Manila                             16.2                        4.1
# City of Mandaluyong                        12.4                        5.5
# City of San Juan                           13.7                        4.6
# Quezon City                                 9.1                        3.2
#
#                                                       4                 5   \
# Unnamed: 0           Cash Receipts from Domestic Sources  Rentals Received
# City of Manila                                       2.9               0.5
# City of Mandaluyong                                  1.9               0.6
# City of San Juan                                     1.9               0.7
# Quezon City                                          1.6               1.2
#
#                            6        7          8   \
# Unnamed: 0           Interest  Pension  Dividends
# City of Manila            0.0      1.6        0.4
# City of Mandaluyong       0.1      3.3        0.1
# City of San Juan          0.1      3.5        6.2
# Quezon City               0.1      2.7        0.7
#
#                                               9   \
# Unnamed: 0           Other Source of Income, NEC
# City of Manila                               0.1
# City of Mandaluyong                          0.1
# City of San Juan                             0.0
# Quezon City                                  0.0
#
#                                                                     10  \
# Unnamed: 0           Net Share of Crops, Aquaculture Products or Li...
# City of Manila                                                     0.0
# City of Mandaluyong                                                0.0
# City of San Juan                                                   0.0
# Quezon City                                                        0.0
#
#                                                                 11  \
# Unnamed: 0           Net Receipt from Family Sustenance Activities
# City of Manila                                                 0.0
# City of Mandaluyong                                            0.0
# City of San Juan                                               0.1
# Quezon City                                                    0.0
#
#                                     12            13
# Unnamed: 0           Received as Gifts  Imputed Rent
# City of Manila                     1.5           8.5
# City of Mandaluyong                1.5          11.0
# City of San Juan                   1.0          12.5
# Quezon City                        0.9          11.0

# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# ### **1. Does having a higher percent in Cash Receipts from Abroad correlate to higher percent of spending in Education?**
# Null and Alternative Hypotheses:
# - H0: Cash receipts have no positive correlation with education.
# - H1: Cash receipts have a positive correlation with education.
#
# We will be using **Pearson’s Correlation** with a **one-tailed test** and significance level **0.05** for hypothesis testing.
#
# To see the correlation of these variables over time, we decided to use data from all tables. We isolated the key variables (Cash Receipts from Abroad and Education) and then used the pearsonr() function to find the correlation between each series with the same year. Lastly, we get the average across all years to get the correlation across all years.

# %%
#Get only the needed variables into a series
IEQ1 = {}
IEQ1.update({"Income18":IE["Income18"][3]})
IEQ1.update({"Income21":IE["Income21"][3]})
IEQ1.update({"Income23":IE["Income23"][3]})
IEQ1.update({"Expenditure18":IE["Expenditure18"][13]})
IEQ1.update({"Expenditure21":IE["Expenditure21"][13]})
IEQ1.update({"Expenditure23":IE["Expenditure23"][13]})

#Remove the label row and set all data types to numeric
for df in IEQ1:
  IEQ1[df] = IEQ1[df].iloc[1:]
  IEQ1[df] = list(IEQ1[df])

#Using pearson's correlation
meanCorr = 0
meanPVal = 0

correlation, p_value = pearsonr(IEQ1["Income18"], IEQ1["Expenditure18"])
if correlation > 0:
    p_one_tailed = p_value / 2
else:
    p_one_tailed = 1 - (p_value / 2)
print("2018 Correlation coefficient (r):", correlation)
print("2018 P-value (One-tailed):", p_one_tailed)
print()
meanCorr += correlation
meanPVal += p_one_tailed

correlation, p_value = pearsonr(IEQ1["Income21"], IEQ1["Expenditure21"])
if correlation > 0:
    p_one_tailed = p_value / 2
else:
    p_one_tailed = 1 - (p_value / 2)
print("2021 Correlation coefficient (r):", correlation)
print("2021 P-value (One-tailed):", p_one_tailed)
print()
meanCorr += correlation
meanPVal += p_one_tailed

correlation, p_value = pearsonr(IEQ1["Income23"], IEQ1["Expenditure23"])
if correlation > 0:
    p_one_tailed = p_value / 2
else:
    p_one_tailed = 1 - (p_value / 2)
print("2023 Correlation coefficient (r):", correlation)
print("2023 P-value (One-tailed):", p_one_tailed)
print()
meanCorr += correlation
meanPVal += p_one_tailed
meanCorr /= 3
meanPVal /= 3


print("Correlation coefficient (r):", meanCorr)
print("P-value (One-tailed):", meanPVal)
# Out:
# 2018 Correlation coefficient (r): -0.09994651691724583
# 2018 P-value (One-tailed): 0.8581774581604898
#
# 2021 Correlation coefficient (r): 0.10821461394013614
# 2021 P-value (One-tailed): 0.12274641446433907
#
# 2023 Correlation coefficient (r): 0.2640734878696867
# 2023 P-value (One-tailed): 0.0020075255966444387
#
# Correlation coefficient (r): 0.09078052829752566
# P-value (One-tailed): 0.32764379940715777

# %% [markdown]
# Since p-value (~0.0328) > significance level (0.05), we **do not reject** the null hypothesis.
#
# We then conclude that cash receipts have no positive correlation with education.
#
# The following code visualizes the data across 2018, 2021, and 2023.

# %%
dfNumeric = pd.DataFrame({
    "Cash Receipts from Abroad": IEQ1["Income18"],
    "Education": IEQ1["Expenditure18"]
})

plt.figure(figsize=(10, 6))
sns.regplot(
    data=dfNumeric,
    x="Cash Receipts from Abroad",
    y="Education",
    scatter_kws={'s': 50},
    line_kws={'color': 'red'}
)
plt.title("Relationship Between Cash Receipts from Abroad and Education (2018)")
plt.xlabel("Cash Receipts from Abroad (%)")
plt.ylabel("Education (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

dfNumeric = pd.DataFrame({
    "Cash Receipts from Abroad": IEQ1["Income21"],
    "Education": IEQ1["Expenditure21"]
})

plt.figure(figsize=(10, 6))
sns.regplot(
    data=dfNumeric,
    x="Cash Receipts from Abroad",
    y="Education",
    scatter_kws={'s': 50},
    line_kws={'color': 'red'}
)
plt.title("Relationship Between Cash Receipts from Abroad and Education (2021)")
plt.xlabel("Cash Receipts from Abroad (%)")
plt.ylabel("Education (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

dfNumeric = pd.DataFrame({
    "Cash Receipts from Abroad": IEQ1["Income23"],
    "Education": IEQ1["Expenditure23"]
})

plt.figure(figsize=(10, 6))
sns.regplot(
    data=dfNumeric,
    x="Cash Receipts from Abroad",
    y="Education",
    scatter_kws={'s': 50},
    line_kws={'color': 'red'}
)
plt.title("Relationship Between Cash Receipts from Abroad and Education (2023)")
plt.xlabel("Cash Receipts from Abroad (%)")
plt.ylabel("Education (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q3 (Don't know how to do Q2 yet)

# %%
IEQ3 = pd.DataFrame({'2018': IE["Expenditure18"][9],
                     '2021': IE["Expenditure21"][9],
                     '2023': IE["Expenditure23"][9]})
IEQ3 = IEQ3.iloc[1:]
IEQ3 = IEQ3.apply(pd.to_numeric)
IEQ3.hist()
# Out:
# array([[<Axes: title={'center': '2018'}>,
#         <Axes: title={'center': '2021'}>],
#        [<Axes: title={'center': '2023'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### **3.  Is there a significant increase in Health spending from 2018 to 2023?
#
# Null and Alternative Hypotheses:
# - H0: There is no significant difference in health spending between 2018 and 2023.
# - H1: Health spending in 2023 is significantly higher.
#
# Using a One-tailed Independent Samples t-test
# (Assuming data is normally distributed, or sample size is large)

# %% [markdown]
# We will use **exploratory data analysis (EDA)** and **inferential statistics** to:
# - Summarize the central tendencies and variability of health spending
# - Visualize the data distribution
# - Conduct a hypothesis test to check for a statistically significant increase

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

sns.set(style="whitegrid")

# %% [markdown]
# ## Step 1: Load the Dataset
#
# We begin by loading the dataset that contains health spending values for the years 2018, 2021, and 2023.

# %%
#Table 7. 2018, 2021 and 2023p Share to Total Family Expenditure, by Region, Province and HUC
Expenditure18 = pd.read_csv("E18.csv")
Expenditure21 = pd.read_csv("E21.csv")
Expenditure23 = pd.read_csv("E23.csv")

Expenditure18.head()
Expenditure21.head()
Expenditure23.head()
# Out:
#                                           Unnamed: 0  PHILIPPINES  \
# 0                        Share to Family Expenditure        100.0
# 1                   Food and Non-Alcoholic Beverages         40.9
# 2                              Food Consumed at Home         35.3
# 3           Food Regularly Consumed Outside the Home          5.6
# 4      Service for Processing Primary Goods for F...          0.0
#
#   NATIONAL CAPITAL REGION City of Manila  City of Mandaluyong  \
# 0                  100.0          100.0                 100.0
# 1                   37.7           44.1                  36.2
# 2                   27.8           30.2                  25.3
# 3                    9.9           13.9                  10.9
# 4                    -              -                     0.0
#
#   City of San Juan Quezon City City of Marikina  City of Pasig  \
# 0           100.0       100.0            100.0           100.0
# 1            31.4        39.8             35.4            32.0
# 2            22.5        26.3             24.5            25.2
# 3             9.0        13.5             10.9             6.8
# 4             -           -                -               0.0
#
#   City of Caloocan  ... Dinagat Islands  \
# 0           100.0   ...          100.0
# 1            40.9   ...           45.2
# 2            32.8   ...           44.7
# 3             8.2   ...            0.6
# 4             -     ...            -
#
#   BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (includes the 63 barangays from Cotabato for 2023)2/  \
# 0                                              100.0
# 1                                               57.5
# 2                                               54.3
# 3                                                3.2
# 4                                                0.0
#
#    Basilan  Lanao Del Sur Maguindanao Maguindanao del Sur  \
# 0   100.0           100.0       100.0               100.0
# 1    55.1            62.5        55.2                56.7
# 2    53.8            58.7        51.0                51.8
# 3     1.4             3.8         4.2                 4.8
# 4     0.0             0.0         0.0                 0.0
#
#   Maguindanao del Norte   Sulu Tawi-Tawi Cotabato City
# 0                100.0   100.0       100           100
# 1                 53.6    64.7      46.3            47
# 2                 50.1    63.2      46.1          41.6
# 3                  3.6     1.5       0.2           5.3
# 4                  -       0.0         0             -
#
# [5 rows x 139 columns]

# %% [markdown]
# ## Step 2: Data Cleaning
#
# We'll inspect the dataset for missing values and ensure it contains only the necessary years (2018, 2021, and 2023).

# %%
# Check for missing values in each dataset
print("Missing values in 2018 data:\n", Expenditure18.isnull().sum(), "\n")
print("Missing values in 2021 data:\n", Expenditure21.isnull().sum(), "\n")
print("Missing values in 2023 data:\n", Expenditure23.isnull().sum(), "\n")

# Drop rows with missing values (if necessary)
Expenditure18.dropna(inplace=True)
Expenditure21.dropna(inplace=True)
Expenditure23.dropna(inplace=True)

# First, check the actual column names in each DataFrame
print("2018 columns:", Expenditure18.columns.tolist())
print("2021 columns:", Expenditure21.columns.tolist())
print("2023 columns:", Expenditure23.columns.tolist())

# organize column names

# Example with a placeholder - replace 'actual_column_name' with the correct column name from your data
health18 = Expenditure18[Expenditure18['actual_column_name'] == 'Health'].copy()
health21 = Expenditure21[Expenditure21['actual_column_name'] == 'Health'].copy()
health23 = Expenditure23[Expenditure23['actual_column_name'] == 'Health'].copy()

# Add year column to each
health18['Year'] = 2018
health21['Year'] = 2021
health23['Year'] = 2023

# Combine all three into one DataFrame
combined_health = pd.concat([health18, health21, health23], ignore_index=True)

# Preview result
combined_health.head()
# Out:
# Missing values in 2018 data:
#  Unnamed: 0                  0
# PHILIPPINES                 0
# NATIONAL CAPITAL REGION     0
# City of Manila              0
# City of Mandaluyong         0
#                            ..
# Maguindanao del Sur        20
# Maguindanao del Norte      20
# Sulu                        0
# Tawi-Tawi                   0
# Cotabato City               0
# Length: 139, dtype: int64
#
# Missing values in 2021 data:
#  Unnamed: 0                  0
# PHILIPPINES                 0
# NATIONAL CAPITAL REGION     0
# City of Manila              0
# City of Mandaluyong         0
#                            ..
# Maguindanao del Sur        20
# Maguindanao del Norte      20
# Sulu                        0
# Tawi-Tawi                   0
# Cotabato City               0
# Length: 139, dtype: int64
#
# Missing values in 2023 data:
#  Unnamed: 0                 0
# PHILIPPINES                0
# NATIONAL CAPITAL REGION    0
# City of Manila             0
# City of Mandaluyong        0
#                           ..
# Maguindanao del Sur        0
# Maguindanao del Norte      0
# Sulu                       0
# Tawi-Tawi                  0
# Cotabato City              0
# Length: 139, dtype: int64
#
# 2018 columns: ['Unnamed: 0', 'PHILIPPINES', 'NATIONAL CAPITAL REGION', 'City of Manila', 'City of Mandaluyong', 'City of San Juan', 'Quezon City', 'City of Marikina', 'City of Pasig', 'City of Caloocan', 'City of Malabon', 'City of Navotas', 'City of Valenzuela', 'City of Las Pi?as', 'City of Muntinlupa', 'City of Para?aque', 'Pasay City', 'City of Makati', 'Pateros', 'City of Taguig', 'CAR - CORDILLERA ADMINISTRATIVE REGION', 'Abra', 'Benguet (Excluding City of Baguio)', 'City of Baguio', 'Ifugao', 'Kalinga', 'Mountain Province', 'Apayao', 'REGION I - ILOCOS REGION', 'Ilocos Norte', 'Ilocos Sur', 'La Union', 'Pangasinan', 'REGION II - CAGAYAN VALLEY', 'Batanes', 'Cagayan', 'Isabela', 'Nueva Vizcaya', 'Quirino', 'REGION III - CENTRAL LUZON', 'Aurora', 'Bataan', 'Bulacan', 'Nueva Ecija', 'Pampanga (Excluding City of Angeles)', 'City of Angeles', 'Tarlac', 'Zambales (Excluding City of Olongapo)', 'City of Olongapo', 'REGION IVA - CALABARZON', 'Batangas', 'Cavite', 'Laguna', 'Quezon (Excluding City of
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'actual_column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 19
#      14 print("2023 columns:", Expenditure23.columns.tolist())
#      16 # organize column names
#      17
#      18 # Example with a placeholder - replace 'actual_column_name' with the correct column name from your data
# ---> 19 health18 = Expenditure18[Expenditure18['actual_column_name'] == 'Health'].copy()
#      20 health21 = Expenditure21[Expenditure21['actual_column_name'] == 'Health'].copy()
#      21 health23 = Expenditure23[Expenditure23['actual_column_name'] == 'Health'].copy()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'actual_column_name'

# %%
## Step 3: Descriptive Statistics

We now compute summary statistics (mean, median, standard deviation) for each year to understand the distribution and central tendency of health spending.
# Out:
#   Cell In[21], line 3
#     We now compute summary statistics (mean, median, standard deviation) for each year to understand the distribution and central tendency of health spending.
#        ^
# SyntaxError: invalid syntax

# %%
# Load CSV files
E18 = pd.read_csv("E18.csv")
E21 = pd.read_csv("E21.csv")
E23 = pd.read_csv("E23.csv")

# First, check the actual column names in each DataFrame
print("E18 columns:", E18.columns.tolist())
print("E21 columns:", E21.columns.tolist())
print("E23 columns:", E23.columns.tolist())

try:
    # Try the original column name first
    health18 = E18[E18['Expenditure Type'] == 'Health'].copy()
except KeyError:
    # If that fails, check if any of these common variations exist
    if 'Expenditure_Type' in E18.columns:
        health18 = E18[E18['Expenditure_Type'] == 'Health'].copy()
    elif 'ExpenditureType' in E18.columns:
        health18 = E18[E18['ExpenditureType'] == 'Health'].copy()
    else:
        # If none of the expected columns exist, print the available columns
        print("Could not find expenditure type column in E18. Available columns:", E18.columns.tolist())
        health18 = pd.DataFrame()  # Create empty DataFrame as fallback




    # Add year column
    health18['Year'] = 2018
    health21['Year'] = 2021
    health23['Year'] = 2023

    # Combine all into one DataFrame
    combined_health = pd.concat([health18, health21, health23], ignore_index=True)

    # Clean and convert 'Share' column to numeric (removes %, commas if any)
    combined_health['Share'] = combined_health['Share'].replace({',': '', '%': ''}, regex=True)
    combined_health['Share'] = pd.to_numeric(combined_health['Share'], errors='coerce')

    # Drop rows with missing or invalid Share values
    combined_health = combined_health.dropna(subset=['Share'])

    # Group by year and calculate stats
    grouped = combined_health.groupby('Year')['Share']
    
    # Print results (this was incomplete in the original code)
    print(grouped.mean())
else:
    print("Could not process data due to missing columns")
# Out:
# E18 columns: ['Unnamed: 0', 'PHILIPPINES', 'NATIONAL CAPITAL REGION', 'City of Manila', 'City of Mandaluyong', 'City of San Juan', 'Quezon City', 'City of Marikina', 'City of Pasig', 'City of Caloocan', 'City of Malabon', 'City of Navotas', 'City of Valenzuela', 'City of Las Pi?as', 'City of Muntinlupa', 'City of Para?aque', 'Pasay City', 'City of Makati', 'Pateros', 'City of Taguig', 'CAR - CORDILLERA ADMINISTRATIVE REGION', 'Abra', 'Benguet (Excluding City of Baguio)', 
AS', 'Eastern Samar', 'Leyte (Excluding City of Tacloban)', 'City of Tacloban', 'Northern Samar', 'Samar (Western Samar)', 'Southern Leyte', 'Biliran', 'REGION IX - ZAMBOANGA PENINSULA', 'Zamboanga Del Norte', 'Zamboanga Del Sur (Excluding City of Zamboanga)', 'City of Zamboanga', 'Zamboanga Sibugay', 'Isabela City', 'REGION X - NORTHERN MINDANAO', 'Bukidnon', 'Camiguin', 'Lanao Del Norte (Excluding City of Iligan)', 'City of Iligan', 'Misamis Occidental', 'Misamis Oriental (Excluding City of Cagayan De Oro)', 'City of Cagayan De Oro', 'REGION XI - DAVAO REGION', 'Davao Del Norte', 'Davao Del Sur (Excluding City of Davao)', 'City of Davao', 'Davao Oriental', 'Davao De Oro', 'Davao Occidental', 'REGION XII - SOCCSKSARGEN1/', 'Cotabato (North Cotabato)', 'South Cotabato (Excluding City of General Santos)', 'City of General Santos (Dadiangas)', 'Sultan Kudarat', 'Sarangani', 'CARAGA', 'Agusan Del Norte (Excluding City of Butuan)', 'City of Butuan', 'Agusan Del Sur', 'Surigao Del Norte', 'Surigao Del Sur', 'Dinagat Islands', 'BARMM - BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANAO (includes the 63 barangays from Cotabato for 2023)2/', 'Basilan', 'Lanao Del Sur', 'Maguindanao', 'Maguindanao del Sur', 'Maguindanao del Norte', 'Sulu', 'Tawi-Tawi', 'Cotabato City']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Expenditure Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 13
#      11 try:
#      12     # Try the original column name first
# ---> 13     health18 = E18[E18['Expenditure Type'] == 'Health'].copy()
#      14 except KeyError:
#      15     # If that fails, check if any of these common variations exist
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'Expenditure Type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Share'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 37
#      34 combined_health = pd.concat([health18, health21, health23], ignore_index=True)
#      36 # Clean and convert 'Share' column to numeric (removes %, commas if any)
# ---> 37 combined_health['Share'] = combined_health['Share'].replace({',': '', '%': ''}, regex=True)
#      38 combined_health['Share'] = pd.to_numeric(combined_health['Share'], errors='coerce')
#      40 # Drop rows with missing or invalid Share values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Share'

# %% [markdown]
# ## Step 4: Visualizations
#
# We use box plots, histograms, and KDE plots to compare the distribution of health spending between the two years.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set visual style
sns.set(style="whitegrid")

# Boxplot: Compare distributions
plt.figure(figsize=(8, 5))
sns.boxplot(data=combined_health, x='Year', y='Share')
plt.title("Health Spending Distribution by Year")
plt.ylabel("Health Spending (% of Total Expenditure)")
plt.xlabel("Year")
plt.tight_layout()
plt.show()

# %%
# Histogram + KDE (distribution plot)
plt.figure(figsize=(10, 6))
sns.histplot(data=combined_health, x='Share', hue='Year', kde=True, element='step', stat='density')
plt.title("Distribution of Health Spending (2018, 2021, 2023)")
plt.xlabel("Health Spending (% Share)")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5: Percentage Increase in Mean
#
# We calculate how much the mean health spending has increased from 2018 to 2023.

# %%
# Step 5: Percentage Increase in Mean (All Years)

# Compute means
mean_2018 = combined_health[combined_health['Year'] == 2018]['Share'].mean()
mean_2021 = combined_health[combined_health['Year'] == 2021]['Share'].mean()
mean_2023 = combined_health[combined_health['Year'] == 2023]['Share'].mean()

# Compute % increases
increase_18_to_21 = mean_2021 - mean_2018
percent_18_to_21 = (increase_18_to_21 / mean_2018) * 100

increase_21_to_23 = mean_2023 - mean_2021
percent_21_to_23 = (increase_21_to_23 / mean_2021) * 100

increase_18_to_23 = mean_2023 - mean_2018
percent_18_to_23 = (increase_18_to_23 / mean_2018) * 100

# Print results
print("📊 Mean Health Spending by Year")
print(f"2018: {mean_2018:.2f}%")
print(f"2021: {mean_2021:.2f}%")
print(f"2023: {mean_2023:.2f}%\n")

print("📈 Percentage Increases")
print(f"2018 ➡ 2021: {percent_18_to_21:.2f}%")
print(f"2021 ➡ 2023: {percent_21_to_23:.2f}%")
print(f"2018 ➡ 2023: {percent_18_to_23:.2f}%")
# Out:
# 📊 Mean Health Spending by Year
# 2018: 5.50%
# 2021: nan%
# 2023: nan%
#
# 📈 Percentage Increases
# 2018 ➡ 2021: nan%
# 2021 ➡ 2023: nan%
# 2018 ➡ 2023: nan%

# %% [markdown]
# ## Step 6: Hypothesis Testing
#
# We will conduct a one-tailed independent t-test to determine whether the increase in health spending from 2018 to 2023 is statistically significant.
#
# ### 📌 Hypotheses:
# Let μ₁ = mean health spending in 2018
# Let μ₂ = mean health spending in 2023
#
# - **Null Hypothesis (H₀):** μ₁ = μ₂ (no significant difference)
# - **Alternative Hypothesis (H₁):** μ₂ > μ₁ (health spending increased)
#
# We will use a **significance level (α)** of 0.05.

# %%
from scipy.stats import ttest_ind

# Extract samples for 2018 and 2023
spend_2018 = combined_health[combined_health['Year'] == 2018]['Share']
spend_2023 = combined_health[combined_health['Year'] == 2023]['Share']

# Perform two-sample t-test (Welch's test for unequal variances)
t_stat, p_value_two_tailed = ttest_ind(spend_2023, spend_2018, equal_var=False)

# One-tailed p-value since H1: 2023 > 2018
p_value_one_tailed = p_value_two_tailed / 2

# Print results
print("📊 Hypothesis Testing Result")
print(f"T-statistic: {t_stat:.4f}")
print(f"One-tailed P-value: {p_value_one_tailed:.4f}")
# Out:
# 📊 Hypothesis Testing Result
# T-statistic: nan
# One-tailed P-value: nan

# %% [markdown]
# ### **4. Does a higher percentage in income from entrepeneurial activities correlate to higher spending in transport?**
# Here are the Null and Alternative Hypotheses:
# - H0: There is no positive correlation between Entrepeneurial Activities and Transport.
# - H1: There is a positive correlation between Entrepeneurial Activities and Transport.
#
# To solve our rearch question, we will use **Pearson’s Correlation** with a **one-tailed test**, and we will use a significance level of **0.05** for our hypothesis testing.
#
# To get the latest data, we decided to use only the data from 2023. We isolated the key variables (Entrepeneurial Activities and Transport) from Income 2023 and Expenditure 2023 as their own dataframes. Then, we combined them into a new single dataframe.

# %%
EntrepeneurialActivities = IE["Income23"][2]
Transport = IE["Expenditure23"][10]

dfCombined = pd.DataFrame({
    "Entrepreneurial Activities": EntrepeneurialActivities,
    "Transport": Transport
})

dfCombined
# Out:
#                      Entrepreneurial Activities  Transport
# Unnamed: 0           Entrepreneurial Activities  Transport
# City of Manila                             16.2        5.1
# City of Mandaluyong                        12.4        5.2
# City of San Juan                           13.7        6.5
# Quezon City                                 9.1        7.2
# ...                                         ...        ...
# Lanao Del Sur                              45.8        4.1
# Maguindanao                                54.3        5.5
# Sulu                                       74.7        3.8
# Tawi-Tawi                                  49.5        6.8
# Cotabato City                              32.9        6.3
#
# [118 rows x 2 columns]

# %% [markdown]
# We can see that the labels in the first row are redundant, so we removed it from the dataframe.

# %%
dfCombined = dfCombined.drop(dfCombined.index[0])

# %% [markdown]
# You may use this code block to see the current state of our combined dataframe.

# %%
dfCombined
# Out:
#                     Entrepreneurial Activities Transport
# City of Manila                            16.2       5.1
# City of Mandaluyong                       12.4       5.2
# City of San Juan                          13.7       6.5
# Quezon City                                9.1       7.2
# City of Marikina                           9.3       7.4
# ...                                        ...       ...
# Lanao Del Sur                             45.8       4.1
# Maguindanao                               54.3       5.5
# Sulu                                      74.7       3.8
# Tawi-Tawi                                 49.5       6.8
# Cotabato City                             32.9       6.3
#
# [117 rows x 2 columns]

# %% [markdown]
# We will be using Pearson's Correlation to determine the relationship between Entrepeneurial Activities and Transport. To ensure tha the data is compatible with the pearsonr() function, we converted the data into numeric values and stored them in new variables as x (for Entrepeneurial Activities) and y (for Transport).
#
# Afterwards, we used the pearsonr() function to get the correlation coefficient (r) and the p-value. Since pearsonr() calculates the two-tailed p-value by default, we will use a formula to convert the p-value into its one-tailed version.

# %%
x = pd.to_numeric(dfCombined["Entrepreneurial Activities"], errors='coerce')
y = pd.to_numeric(dfCombined["Transport"], errors='coerce')

correlation, p_value = pearsonr(x, y)

if correlation > 0:
    p_one_tailed = p_value / 2
else:
    p_one_tailed = 1 - (p_value / 2)


print("Correlation coefficient (r):", correlation)
print("P-value (One-tailed):", p_one_tailed)
# Out:
# Correlation coefficient (r): -0.3666690419730354
# P-value (One-tailed): 0.999976097073966

# %% [markdown]
# Our p-value is **0.999976097073966**. Since it is **greater** than our level of significance (0.05), we **failed to reject the null hypothesis**. Thus, there is **not enough evidence** to conclude that there is a **positive correlation** between Entrepeneurial Activities and Transport.
#
# On the other hand, our correlation coefficient (r) is **-0.3666690419730354**, which implies that there is a **moderate negative** linear correlation between Entrepeneurial Activities and Transport. This means that as income gained in Entrepeneurial Activities increases, spending for Transport decreases, and vice versa. The graph below provides a visualization on this relationship.

# %%
dfNumeric = pd.DataFrame({
    "Entrepreneurial Activities": x,
    "Transport": y
})

plt.figure(figsize=(10, 6))
sns.regplot(
    data=dfNumeric,
    x="Entrepreneurial Activities",
    y="Transport",
    scatter_kws={'s': 50},
    line_kws={'color': 'red'}
)
plt.title("Relationship Between Entrepreneurial Activities and Transport (2023)")
plt.xlabel("Entrepreneurial Activities (%)")
plt.ylabel("Transport (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Final Answer:** A higher percentage in income from entrepeneurial activities does **not** correlate to higher spending in transport. In fact, an increase in income from entrepeneurial activities correlates to a decrease in spending for transport, and vice versa.
